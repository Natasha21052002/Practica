# %% [markdown]
# # Загрузка данных анкет и проведение МАИ, анализ полученных результатов
# Данные: заполненные анкеты экспертов (таблицы Excel)

# %%
import re
import numpy as np
import pandas as pd
import scipy as sp
import matplotlib.pyplot as plt
from random import randint

# %%
df = pd.read_excel(r'C:\Users\user\аварии\Экс7.xlsx')
df.head()
# Out:
#                                        Тип нарушения  Документация   \
# 0                                      Документация            1.00
# 1               Экспертиза промышленной безопасности           5.00
# 2  Готовность к ликвидации последствий аварий и и...           7.00
# 3  Оформление информационными знаками и знаками б...           0.25
# 4                 Содержание объектов и оборудования           6.00
#
#    Экспертиза промышленной безопасности  \
# 0                                   0.2
# 1                                   1.0
# 2                                   7.0
# 3                                   3.0
# 4                                   0.2
#
#    Готовность к ликвидации последствий аварий и инцидентов  \
# 0                                           0.142857
# 1                                           0.142857
# 2                                           1.000000
# 3                                           0.166667
# 4                                           5.000000
#
#    Оформление информационными знаками и знаками безопасности  \
# 0                                           4.000000
# 1                                           0.333333
# 2                                           6.000000
# 3                                           1.000000
# 4                                           6.000000
#
#    Содержание объектов и оборудования   Охранные зоны (ОЗ)  \
# 0                             0.166667            7.000000
# 1                             5.000000            0.142857
# 2                             0.200000            0.142857
# 3                             0.166667            0.142857
# 4                             1.000000            0.142857
#
#    Организация рабочего процесса и безопасности персонала
# 0                                           8.000000
# 1                                           0.166667
# 2                                           6.000000
# 3                                           0.166667
# 4                                           0.142857

# %%
print('Число строк и столбцов в наборе данных:\n', df.shape)
# Out:
# Число строк и столбцов в наборе данных:
#  (7, 8)

# %%
# типы столбцов 
df.dtypes
# Out:
# Тип нарушения                                                 object
# Документация                                                 float64
# Экспертиза промышленной безопасности                         float64
# Готовность к ликвидации последствий аварий и инцидентов      float64
# Оформление информационными знаками и знаками безопасности    float64
# Содержание объектов и оборудования                           float64
# Охранные зоны (ОЗ)                                           float64
# Организация рабочего процесса и безопасности персонала       float64
# dtype: object

# %%
#удаление столбца типа object для дальнейшей работы с фреймом 
df.pop('Тип нарушения') 
print(df)
# Out:
#    Документация   Экспертиза промышленной безопасности  \
# 0       1.000000                                   0.2
# 1       5.000000                                   1.0
# 2       7.000000                                   7.0
# 3       0.250000                                   3.0
# 4       6.000000                                   0.2
# 5       0.142857                                   7.0
# 6       0.125000                                   6.0
#
#    Готовность к ликвидации последствий аварий и инцидентов  \
# 0                                           0.142857
# 1                                           0.142857
# 2                                           1.000000
# 3                                           0.166667
# 4                                           5.000000
# 5                                           7.000000
# 6                                           0.166667
#
#    Оформление информационными знаками и знаками безопасности  \
# 0                                           4.000000
# 1                                           0.333333
# 2                                           6.000000
# 3                                           1.000000
# 4                                           6.000000
# 5                                           7.000000
# 6                                           6.000000
#
#    Содержание объектов и оборудования   Охранные зоны (ОЗ)  \
# 0                             0.166667            7.000000
# 1                             5.000000            0.142857
# 2                             0.200000            0.142857
# 3                             0.166667            0.142857
# 4                             1.000000            0.142857
# 5                             7.000000            1.000000
# 6                             7.000000            0.142857
#
#    Организация рабочего процесса и безопасности персонала
# 0                                           8.000000
# 1                                           0.166667
# 2                                           6.000000
# 3                                           0.166667
# 4                                           0.142857
# 5                                           7.000000
# 6                                           1.000000

# %%
# типы столбцов 
df.dtypes
# Out:
# Документация                                                 float64
# Экспертиза промышленной безопасности                         float64
# Готовность к ликвидации последствий аварий и инцидентов      float64
# Оформление информационными знаками и знаками безопасности    float64
# Содержание объектов и оборудования                           float64
# Охранные зоны (ОЗ)                                           float64
# Организация рабочего процесса и безопасности персонала       float64
# dtype: object

# %%
# также меням тип данных Документации
df['Документация '] = df['Документация '].astype(float)

# %%
df.loc[:, df.columns[df.dtypes == 'float64']].head(7)
# Out:
#    Документация   Экспертиза промышленной безопасности  \
# 0       1.000000                                   0.2
# 1       5.000000                                   1.0
# 2       7.000000                                   7.0
# 3       0.250000                                   3.0
# 4       6.000000                                   0.2
# 5       0.142857                                   7.0
# 6       0.125000                                   6.0
#
#    Готовность к ликвидации последствий аварий и инцидентов  \
# 0                                           0.142857
# 1                                           0.142857
# 2                                           1.000000
# 3                                           0.166667
# 4                                           5.000000
# 5                                           7.000000
# 6                                           0.166667
#
#    Оформление информационными знаками и знаками безопасности  \
# 0                                           4.000000
# 1                                           0.333333
# 2                                           6.000000
# 3                                           1.000000
# 4                                           6.000000
# 5                                           7.000000
# 6                                           6.000000
#
#    Содержание объектов и оборудования   Охранные зоны (ОЗ)  \
# 0                             0.166667            7.000000
# 1                             5.000000            0.142857
# 2                             0.200000            0.142857
# 3                             0.166667            0.142857
# 4                             1.000000            0.142857
# 5                             7.000000            1.000000
# 6                             7.000000            0.142857
#
#    Организация рабочего процесса и безопасности персонала
# 0                                           8.000000
# 1                                           0.166667
# 2                                           6.000000
# 3                                           0.166667
# 4                                           0.142857
# 5                                           7.000000
# 6                                           1.000000

# %%
DF_1=df[:].copy()

# %%
#Найдем сумму всех столбцов, для того чтобы в дальнейшем пересчитать полученные значения
df.sum ()
# Out:
# Документация                                                 19.517857
# Экспертиза промышленной безопасности                         24.400000
# Готовность к ликвидации последствий аварий и инцидентов      13.619048
# Оформление информационными знаками и знаками безопасности    30.333333
# Содержание объектов и оборудования                           20.533333
# Охранные зоны (ОЗ)                                            8.714286
# Организация рабочего процесса и безопасности персонала       22.476190
# dtype: float64

# %%
# Считаем значения для нашей матрицы, путем деления каждого значения в столбце на сумму столбца
df['new_Документация'] = df['Документация '].astype(float).div(df['Документация '].sum())
df['new_Экспертиза'] = df['Экспертиза промышленной безопасности'].astype(float).div(df['Экспертиза промышленной безопасности'].sum())
df['new_Готовность'] = df['Готовность к ликвидации последствий аварий и инцидентов'].astype(float).div(df['Готовность к ликвидации последствий аварий и инцидентов'].sum())
df['new_Оформление'] = df['Оформление информационными знаками и знаками безопасности'].astype(float).div(df['Оформление информационными знаками и знаками безопасности'].sum())
df['new_Содержание'] = df['Содержание объектов и оборудования '].astype(float).div(df['Содержание объектов и оборудования '].sum())
df['new_ОЗ'] = df['Охранные зоны (ОЗ)'].astype(float).div(df['Охранные зоны (ОЗ)'].sum())
df['new_Организация'] = df['Организация рабочего процесса и безопасности персонала'].astype(float).div(df['Организация рабочего процесса и безопасности персонала'].sum())

# %%
df.head()
# Out:
#    Документация   Экспертиза промышленной безопасности  \
# 0           1.00                                   0.2
# 1           5.00                                   1.0
# 2           7.00                                   7.0
# 3           0.25                                   3.0
# 4           6.00                                   0.2
#
#    Готовность к ликвидации последствий аварий и инцидентов  \
# 0                                           0.142857
# 1                                           0.142857
# 2                                           1.000000
# 3                                           0.166667
# 4                                           5.000000
#
#    Оформление информационными знаками и знаками безопасности  \
# 0                                           4.000000
# 1                                           0.333333
# 2                                           6.000000
# 3                                           1.000000
# 4                                           6.000000
#
#    Содержание объектов и оборудования   Охранные зоны (ОЗ)  \
# 0                             0.166667            7.000000
# 1                             5.000000            0.142857
# 2                             0.200000            0.142857
# 3                             0.166667            0.142857
# 4                             1.000000            0.142857
#
#    Организация рабочего процесса и безопасности персонала  new_Документация  \
# 0                                           8.000000               0.051235
# 1                                           0.166667               0.256176
# 2                                           6.000000               0.358646
# 3                                           0.166667               0.012809
# 4                                           0.142857               0.307411
#
#    new_Экспертиза  new_Готовность  new_Оформление  new_Содержание    new_ОЗ  \
# 0        0.008197        0.010490        0.131868        0.008117  0.803279
# 1        0.040984        0.010490        0.010989        0.243506  0.016393
# 2        0.286885        0.073427        0.197802        0.009740  0.016393
# 3        0.122951        0.012238        0.032967        0.008117  0.016393
# 4        0.008197        0.367133        0.197802        0.048701  0.016393
#
#    new_Организация
# 0         0.355932
# 1         0.007415
# 2         0.266949
# 3         0.007415
# 4         0.006356

# %%
# Получили новую таблицу теперь отделим значения нашей матрицы от основной таблицы
df_new = df[['new_Документация', 'new_Экспертиза', 'new_Готовность', 'new_Оформление', 'new_Содержание', 'new_ОЗ', 'new_Организация']]
df_new
# Out:
#    new_Документация  new_Экспертиза  new_Готовность  new_Оформление  \
# 0          0.051235        0.008197        0.010490        0.131868
# 1          0.256176        0.040984        0.010490        0.010989
# 2          0.358646        0.286885        0.073427        0.197802
# 3          0.012809        0.122951        0.012238        0.032967
# 4          0.307411        0.008197        0.367133        0.197802
# 5          0.007319        0.286885        0.513986        0.230769
# 6          0.006404        0.245902        0.012238        0.197802
#
#    new_Содержание    new_ОЗ  new_Организация
# 0        0.008117  0.803279         0.355932
# 1        0.243506  0.016393         0.007415
# 2        0.009740  0.016393         0.266949
# 3        0.008117  0.016393         0.007415
# 4        0.048701  0.016393         0.006356
# 5        0.340909  0.114754         0.311441
# 6        0.340909  0.016393         0.044492

# %%
#Вычислим средние значение по строке и запишем полученный результот в mean
df_new['mean'] = df_new.mean(axis=1)
df_new.head()
# Out:
# C:\Users\user\anaconda3\envs\envpy3.5\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#    new_Документация  new_Экспертиза  new_Готовность  new_Оформление  \
# 0          0.051235        0.008197        0.010490        0.131868
# 1          0.256176        0.040984        0.010490        0.010989
# 2          0.358646        0.286885        0.073427        0.197802
# 3          0.012809        0.122951        0.012238        0.032967
# 4          0.307411        0.008197        0.367133        0.197802
#
#    new_Содержание    new_ОЗ  new_Организация      mean
# 0        0.008117  0.803279         0.355932  0.195588
# 1        0.243506  0.016393         0.007415  0.083708
# 2        0.009740  0.016393         0.266949  0.172835
# 3        0.008117  0.016393         0.007415  0.030413
# 4        0.048701  0.016393         0.006356  0.135999

# %%
#проверка, среднее значение в сумме должно быть равно 1
df_new['mean'].sum()
# Out:
# 0.9999999999999999

# %%
# Далее проведем проверку на согласованность, 
#для этого создадим из нашей полученной выше таблицы матрицы для дальнейшего их перемножения
df_new8 =df_new['mean']

# удаляем из нашей таблицы значениея столбцы mean
#df_new.pop('mean')

df_new1 =DF_1.loc[0]

df_new2 =DF_1.loc[1]

df_new3 =DF_1.loc[2]

df_new4 =DF_1.loc[3]

df_new5 =DF_1.loc[4]

df_new6 =DF_1.loc[5]

df_new7 =DF_1.loc[6]

# %%
#Проверка на согласованность
res1 = np.dot(df_new1,df_new8)
print(res1)
res2 = np.dot(df_new2,df_new8)
print(res2)
res3 = np.dot(df_new3,df_new8)
print(res3)
res4 = np.dot(df_new4,df_new8)
print(res4)
res5 = np.dot(df_new5,df_new8)
print(res5)
res6 = np.dot(df_new6,df_new8)
print(res6)
res7 = np.dot(df_new7,df_new8)
print(res7)
# Out:
# 3.1749905779670975
# 1.8339051521755527
# 3.1151317837029744
# 0.43933809816106545
# 2.427414146423995
# 4.110769329591632
# 1.8502771170851433

# %%
sum_new = res1 + res2 + res3 + res4 + res5 + res6 + res7
print(sum_new)
# Out:
# 16.951826205107462

# %%
# Вычислем значения CI, RI, CR
CI = (sum_new - 7)/(7-1)
print(CI)
RI = (1.98*(7-2))/7
print(RI)
CR = CI/RI
print(CR)
# Out:
# 1.6586377008512436
# 1.4142857142857144
# 1.1727741319150207

# %%
# Получилось, что значение CR=1.17, что большее 0,1 значит матрицу нельзя считать согласованной
# Проделаем аналогичные действия с другими экспертами
