# %% [markdown]
# # Загрузка данных анкет и проведение МАИ, анализ полученных результатов
# Данные: заполненные анкеты экспертов (таблицы Excel)

# %%
import re
import numpy as np
import pandas as pd
import scipy as sp
import matplotlib.pyplot as plt
from random import randint

# %%
df = pd.read_excel(r'C:\Users\user\аварии\Экс1.xlsx')
df.head()
# Out:
#                                        Тип нарушения  Документация   \
# 0                                      Документация        1.000000
# 1               Экспертиза промышленной безопасности       2.333333
# 2  Готовность к ликвидации последствий аварий и и...       4.000000
# 3  Оформление информационными знаками и знаками б...       3.000000
# 4                 Содержание объектов и оборудования       9.000000
#
#    Экспертиза промышленной безопасности  \
# 0                              0.428571
# 1                              1.000000
# 2                              2.000000
# 3                              1.250000
# 4                              9.000000
#
#    Готовность к ликвидации последствий аварий и инцидентов  \
# 0                                           0.250000
# 1                                           0.500000
# 2                                           1.000000
# 3                                           0.111111
# 4                                           1.000000
#
#    Оформление информационными знаками и знаками безопасности  \
# 0                                           0.333333
# 1                                           0.800000
# 2                                           9.000000
# 3                                           1.000000
# 4                                           4.000000
#
#    Содержание объектов и оборудования   Охранные зоны (ОЗ)  \
# 0                             0.111111            0.222222
# 1                             0.111111            0.222222
# 2                             1.000000            1.000000
# 3                             0.250000            0.285714
# 4                             1.000000            1.125000
#
#    Организация рабочего процесса и безопасности персонала
# 0                                           0.111111
# 1                                           0.111111
# 2                                           1.000000
# 3                                           0.222222
# 4                                           1.000000

# %%
print('Число строк и столбцов в наборе данных:\n', df.shape)
# Out:
# Число строк и столбцов в наборе данных:
#  (7, 8)

# %%
# типы столбцов 
df.dtypes
# Out:
# Тип нарушения                                                 object
# Документация                                                 float64
# Экспертиза промышленной безопасности                         float64
# Готовность к ликвидации последствий аварий и инцидентов      float64
# Оформление информационными знаками и знаками безопасности    float64
# Содержание объектов и оборудования                           float64
# Охранные зоны (ОЗ)                                           float64
# Организация рабочего процесса и безопасности персонала       float64
# dtype: object

# %%
#удаление столбца типа object для дальнейшей работы с фреймом 
df.pop('Тип нарушения') 
print(df)
# Out:
#    Документация   Экспертиза промышленной безопасности  \
# 0       1.000000                              0.428571
# 1       2.333333                              1.000000
# 2       4.000000                              2.000000
# 3       3.000000                              1.250000
# 4       9.000000                              9.000000
# 5       4.500000                              4.500000
# 6       9.000000                              9.000000
#
#    Готовность к ликвидации последствий аварий и инцидентов  \
# 0                                           0.250000
# 1                                           0.500000
# 2                                           1.000000
# 3                                           0.111111
# 4                                           1.000000
# 5                                           1.000000
# 6                                           1.000000
#
#    Оформление информационными знаками и знаками безопасности  \
# 0                                           0.333333
# 1                                           0.800000
# 2                                           9.000000
# 3                                           1.000000
# 4                                           4.000000
# 5                                           3.500000
# 6                                           4.500000
#
#    Содержание объектов и оборудования   Охранные зоны (ОЗ)  \
# 0                             0.111111            0.222222
# 1                             0.111111            0.222222
# 2                             1.000000            1.000000
# 3                             0.250000            0.285714
# 4                             1.000000            1.125000
# 5                             0.888889            1.000000
# 6                             1.000000            1.125000
#
#    Организация рабочего процесса и безопасности персонала
# 0                                           0.111111
# 1                                           0.111111
# 2                                           1.000000
# 3                                           0.222222
# 4                                           1.000000
# 5                                           0.888889
# 6                                           1.000000

# %%
# типы столбцов 
df.dtypes
# Out:
# Документация                                                 float64
# Экспертиза промышленной безопасности                         float64
# Готовность к ликвидации последствий аварий и инцидентов      float64
# Оформление информационными знаками и знаками безопасности    float64
# Содержание объектов и оборудования                           float64
# Охранные зоны (ОЗ)                                           float64
# Организация рабочего процесса и безопасности персонала       float64
# dtype: object

# %%
# также меням тип данных Документации
df['Документация '] = df['Документация '].astype(float)

# %%
df.loc[:, df.columns[df.dtypes == 'float64']].head(7)
# Out:
#    Документация   Экспертиза промышленной безопасности  \
# 0       1.000000                              0.428571
# 1       2.333333                              1.000000
# 2       4.000000                              2.000000
# 3       3.000000                              1.250000
# 4       9.000000                              9.000000
# 5       4.500000                              4.500000
# 6       9.000000                              9.000000
#
#    Готовность к ликвидации последствий аварий и инцидентов  \
# 0                                           0.250000
# 1                                           0.500000
# 2                                           1.000000
# 3                                           0.111111
# 4                                           1.000000
# 5                                           1.000000
# 6                                           1.000000
#
#    Оформление информационными знаками и знаками безопасности  \
# 0                                           0.333333
# 1                                           0.800000
# 2                                           9.000000
# 3                                           1.000000
# 4                                           4.000000
# 5                                           3.500000
# 6                                           4.500000
#
#    Содержание объектов и оборудования   Охранные зоны (ОЗ)  \
# 0                             0.111111            0.222222
# 1                             0.111111            0.222222
# 2                             1.000000            1.000000
# 3                             0.250000            0.285714
# 4                             1.000000            1.125000
# 5                             0.888889            1.000000
# 6                             1.000000            1.125000
#
#    Организация рабочего процесса и безопасности персонала
# 0                                           0.111111
# 1                                           0.111111
# 2                                           1.000000
# 3                                           0.222222
# 4                                           1.000000
# 5                                           0.888889
# 6                                           1.000000

# %%
DF_1=df[:].copy()

# %%
#Найдем сумму всех столбцов, для того чтобы в дальнейшем пересчитать полученные значения
df.sum ()
# Out:
# Документация                                                 32.833333
# Экспертиза промышленной безопасности                         27.178571
# Готовность к ликвидации последствий аварий и инцидентов       4.861111
# Оформление информационными знаками и знаками безопасности    23.133333
# Содержание объектов и оборудования                            4.361111
# Охранные зоны (ОЗ)                                            4.980159
# Организация рабочего процесса и безопасности персонала        4.333333
# dtype: float64

# %%
# Считаем значения для нашей матрицы, путем деления каждого значения в столбце на сумму столбца
df['new_Документация'] = df['Документация '].astype(float).div(df['Документация '].sum())
df['new_Экспертиза'] = df['Экспертиза промышленной безопасности'].astype(float).div(df['Экспертиза промышленной безопасности'].sum())
df['new_Готовность'] = df['Готовность к ликвидации последствий аварий и инцидентов'].astype(float).div(df['Готовность к ликвидации последствий аварий и инцидентов'].sum())
df['new_Оформление'] = df['Оформление информационными знаками и знаками безопасности'].astype(float).div(df['Оформление информационными знаками и знаками безопасности'].sum())
df['new_Содержание'] = df['Содержание объектов и оборудования '].astype(float).div(df['Содержание объектов и оборудования '].sum())
df['new_ОЗ'] = df['Охранные зоны (ОЗ)'].astype(float).div(df['Охранные зоны (ОЗ)'].sum())
df['new_Организация'] = df['Организация рабочего процесса и безопасности персонала'].astype(float).div(df['Организация рабочего процесса и безопасности персонала'].sum())

# %%
df.head()
# Out:
#    Документация   Экспертиза промышленной безопасности  \
# 0       1.000000                              0.428571
# 1       2.333333                              1.000000
# 2       4.000000                              2.000000
# 3       3.000000                              1.250000
# 4       9.000000                              9.000000
#
#    Готовность к ликвидации последствий аварий и инцидентов  \
# 0                                           0.250000
# 1                                           0.500000
# 2                                           1.000000
# 3                                           0.111111
# 4                                           1.000000
#
#    Оформление информационными знаками и знаками безопасности  \
# 0                                           0.333333
# 1                                           0.800000
# 2                                           9.000000
# 3                                           1.000000
# 4                                           4.000000
#
#    Содержание объектов и оборудования   Охранные зоны (ОЗ)  \
# 0                             0.111111            0.222222
# 1                             0.111111            0.222222
# 2                             1.000000            1.000000
# 3                             0.250000            0.285714
# 4                             1.000000            1.125000
#
#    Организация рабочего процесса и безопасности персонала  new_Документация  \
# 0                                           0.111111               0.030457
# 1                                           0.111111               0.071066
# 2                                           1.000000               0.121827
# 3                                           0.222222               0.091371
# 4                                           1.000000               0.274112
#
#    new_Экспертиза  new_Готовность  new_Оформление  new_Содержание    new_ОЗ  \
# 0        0.015769        0.051429        0.014409        0.025478  0.044622
# 1        0.036794        0.102857        0.034582        0.025478  0.044622
# 2        0.073587        0.205714        0.389049        0.229299  0.200797
# 3        0.045992        0.022857        0.043228        0.057325  0.057371
# 4        0.331143        0.205714        0.172911        0.229299  0.225896
#
#    new_Организация
# 0         0.025641
# 1         0.025641
# 2         0.230769
# 3         0.051282
# 4         0.230769

# %%
# Получили новую таблицу теперь отделим значения нашей матрицы от основной таблицы
df_new = df[['new_Документация', 'new_Экспертиза', 'new_Готовность', 'new_Оформление', 'new_Содержание', 'new_ОЗ', 'new_Организация']]
df_new
# Out:
#    new_Документация  new_Экспертиза  new_Готовность  new_Оформление  \
# 0          0.030457        0.015769        0.051429        0.014409
# 1          0.071066        0.036794        0.102857        0.034582
# 2          0.121827        0.073587        0.205714        0.389049
# 3          0.091371        0.045992        0.022857        0.043228
# 4          0.274112        0.331143        0.205714        0.172911
# 5          0.137056        0.165572        0.205714        0.151297
# 6          0.274112        0.331143        0.205714        0.194524
#
#    new_Содержание    new_ОЗ  new_Организация
# 0        0.025478  0.044622         0.025641
# 1        0.025478  0.044622         0.025641
# 2        0.229299  0.200797         0.230769
# 3        0.057325  0.057371         0.051282
# 4        0.229299  0.225896         0.230769
# 5        0.203822  0.200797         0.205128
# 6        0.229299  0.225896         0.230769

# %%
#Вычислим средние значение по строке и запишем полученный результот в mean
df_new['mean'] = df_new.mean(axis=1)
df_new.head()
# Out:
# C:\Users\user\anaconda3\envs\envpy3.5\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#    new_Документация  new_Экспертиза  new_Готовность  new_Оформление  \
# 0          0.030457        0.015769        0.051429        0.014409
# 1          0.071066        0.036794        0.102857        0.034582
# 2          0.121827        0.073587        0.205714        0.389049
# 3          0.091371        0.045992        0.022857        0.043228
# 4          0.274112        0.331143        0.205714        0.172911
#
#    new_Содержание    new_ОЗ  new_Организация      mean
# 0        0.025478  0.044622         0.025641  0.029686
# 1        0.025478  0.044622         0.025641  0.048720
# 2        0.229299  0.200797         0.230769  0.207292
# 3        0.057325  0.057371         0.051282  0.052775
# 4        0.229299  0.225896         0.230769  0.238549

# %%
#проверка, среднее значение в сумме должно быть равно 1
df_new['mean'].sum()
# Out:
# 1.0

# %%
# Далее проведем проверку на согласованность, 
#для этого создадим из нашей полученной выше таблицы матрицы для дальнейшего их перемножения
df_new8 =df_new['mean']

# удаляем из нашей таблицы значениея столбцы mean
#df_new.pop('mean')

df_new1 =DF_1.loc[0]

df_new2 =DF_1.loc[1]

df_new3 =DF_1.loc[2]

df_new4 =DF_1.loc[3]

df_new5 =DF_1.loc[4]

df_new6 =DF_1.loc[5]

df_new7 =DF_1.loc[6]

# %%
#Проверка на согласованность
res1 = np.dot(df_new1,df_new8)
print(res1)
res2 = np.dot(df_new2,df_new8)
print(res2)
res3 = np.dot(df_new3,df_new8)
print(res3)
res4 = np.dot(df_new4,df_new8)
print(res4)
res5 = np.dot(df_new5,df_new8)
print(res5)
res6 = np.dot(df_new6,df_new8)
print(res6)
res7 = np.dot(df_new7,df_new8)
print(res7)
# Out:
# 0.2136327944403315
# 0.35750567862183025
# 1.5599784570005817
# 0.3909120329003024
# 1.8082414875227695
# 1.3530048480597225
# 1.834628979847828

# %%
sum_new = res1 + res2 + res3 + res4 + res5 + res6 + res7
print(sum_new)
# Out:
# 7.517904278393366

# %%
# Вычислем значения CI, RI, CR
CI = (sum_new - 7)/(7-1)
print(CI)
RI = (1.98*(7-2))/7
print(RI)
CR = CI/RI
print(CR)
# Out:
# 0.08631737973222764
# 1.4142857142857144
# 0.061032490719756916

# %%
# Получилось, что значение CR=0.06, что менеше 0,1 значит матрицу можно считать согласованной
# Проделаем аналогичные действия с другими экспертами
