# %% [markdown]
# # Загрузка данных анкет и проведение МАИ, анализ полученных результатов
# Данные: заполненные анкеты экспертов (таблицы Excel)

# %%
import re
import numpy as np
import pandas as pd
import scipy as sp
import matplotlib.pyplot as plt
from random import randint

# %%
df = pd.read_excel(r'C:\Users\user\аварии\Экс2.xlsx')
df.head()
# Out:
#                                        Тип нарушения  Документация   \
# 0                                      Документация        1.000000
# 1               Экспертиза промышленной безопасности       1.400000
# 2  Готовность к ликвидации последствий аварий и и...       1.000000
# 3  Оформление информационными знаками и знаками б...       0.428571
# 4                 Содержание объектов и оборудования       1.000000
#
#    Экспертиза промышленной безопасности  \
# 0                              0.714286
# 1                              1.000000
# 2                              3.000000
# 3                              0.600000
# 4                              1.000000
#
#    Готовность к ликвидации последствий аварий и инцидентов  \
# 0                                           1.000000
# 1                                           0.333333
# 2                                           1.000000
# 3                                           0.333333
# 4                                           1.000000
#
#    Оформление информационными знаками и знаками безопасности  \
# 0                                           2.333333
# 1                                           1.666667
# 2                                           3.000000
# 3                                           1.000000
# 4                                           1.666667
#
#    Содержание объектов и оборудования   Охранные зоны (ОЗ)  \
# 0                                  1.0            0.714286
# 1                                  1.0            1.000000
# 2                                  1.0            0.714286
# 3                                  0.6            0.600000
# 4                                  1.0            1.285714
#
#    Организация рабочего процесса и безопасности персонала
# 0                                           1.000000
# 1                                           1.000000
# 2                                           0.777778
# 3                                           0.333333
# 4                                           1.000000

# %%
print('Число строк и столбцов в наборе данных:\n', df.shape)
# Out:
# Число строк и столбцов в наборе данных:
#  (7, 8)

# %%
# типы столбцов 
df.dtypes
# Out:
# Тип нарушения                                                 object
# Документация                                                 float64
# Экспертиза промышленной безопасности                         float64
# Готовность к ликвидации последствий аварий и инцидентов      float64
# Оформление информационными знаками и знаками безопасности    float64
# Содержание объектов и оборудования                           float64
# Охранные зоны (ОЗ)                                           float64
# Организация рабочего процесса и безопасности персонала       float64
# dtype: object

# %%
#удаление столбца типа object для дальнейшей работы с фреймом 
df.pop('Тип нарушения') 
print(df)
# Out:
#    Документация   Экспертиза промышленной безопасности  \
# 0       1.000000                              0.714286
# 1       1.400000                              1.000000
# 2       1.000000                              3.000000
# 3       0.428571                              0.600000
# 4       1.000000                              1.000000
# 5       1.400000                              1.000000
# 6       1.000000                              1.000000
#
#    Готовность к ликвидации последствий аварий и инцидентов  \
# 0                                           1.000000
# 1                                           0.333333
# 2                                           1.000000
# 3                                           0.333333
# 4                                           1.000000
# 5                                           1.400000
# 6                                           1.285714
#
#    Оформление информационными знаками и знаками безопасности  \
# 0                                           2.333333
# 1                                           1.666667
# 2                                           3.000000
# 3                                           1.000000
# 4                                           1.666667
# 5                                           1.666667
# 6                                           3.000000
#
#    Содержание объектов и оборудования   Охранные зоны (ОЗ)  \
# 0                             1.000000            0.714286
# 1                             1.000000            1.000000
# 2                             1.000000            0.714286
# 3                             0.600000            0.600000
# 4                             1.000000            1.285714
# 5                             0.777778            1.000000
# 6                             1.000000            1.285714
#
#    Организация рабочего процесса и безопасности персонала
# 0                                           1.000000
# 1                                           1.000000
# 2                                           0.777778
# 3                                           0.333333
# 4                                           1.000000
# 5                                           0.777778
# 6                                           1.000000

# %%
# типы столбцов 
df.dtypes
# Out:
# Документация                                                 float64
# Экспертиза промышленной безопасности                         float64
# Готовность к ликвидации последствий аварий и инцидентов      float64
# Оформление информационными знаками и знаками безопасности    float64
# Содержание объектов и оборудования                           float64
# Охранные зоны (ОЗ)                                           float64
# Организация рабочего процесса и безопасности персонала       float64
# dtype: object

# %%
# также меням тип данных Документации
df['Документация '] = df['Документация '].astype(float)

# %%
df.loc[:, df.columns[df.dtypes == 'float64']].head(7)
# Out:
#    Документация   Экспертиза промышленной безопасности  \
# 0       1.000000                              0.714286
# 1       1.400000                              1.000000
# 2       1.000000                              3.000000
# 3       0.428571                              0.600000
# 4       1.000000                              1.000000
# 5       1.400000                              1.000000
# 6       1.000000                              1.000000
#
#    Готовность к ликвидации последствий аварий и инцидентов  \
# 0                                           1.000000
# 1                                           0.333333
# 2                                           1.000000
# 3                                           0.333333
# 4                                           1.000000
# 5                                           1.400000
# 6                                           1.285714
#
#    Оформление информационными знаками и знаками безопасности  \
# 0                                           2.333333
# 1                                           1.666667
# 2                                           3.000000
# 3                                           1.000000
# 4                                           1.666667
# 5                                           1.666667
# 6                                           3.000000
#
#    Содержание объектов и оборудования   Охранные зоны (ОЗ)  \
# 0                             1.000000            0.714286
# 1                             1.000000            1.000000
# 2                             1.000000            0.714286
# 3                             0.600000            0.600000
# 4                             1.000000            1.285714
# 5                             0.777778            1.000000
# 6                             1.000000            1.285714
#
#    Организация рабочего процесса и безопасности персонала
# 0                                           1.000000
# 1                                           1.000000
# 2                                           0.777778
# 3                                           0.333333
# 4                                           1.000000
# 5                                           0.777778
# 6                                           1.000000

# %%
DF_1=df[:].copy()

# %%
#Найдем сумму всех столбцов, для того чтобы в дальнейшем пересчитать полученные значения
df.sum ()
# Out:
# Документация                                                  7.228571
# Экспертиза промышленной безопасности                          8.314286
# Готовность к ликвидации последствий аварий и инцидентов       6.352381
# Оформление информационными знаками и знаками безопасности    14.333333
# Содержание объектов и оборудования                            6.377778
# Охранные зоны (ОЗ)                                            6.600000
# Организация рабочего процесса и безопасности персонала        5.888889
# dtype: float64

# %%
# Считаем значения для нашей матрицы, путем деления каждого значения в столбце на сумму столбца
df['new_Документация'] = df['Документация '].astype(float).div(df['Документация '].sum())
df['new_Экспертиза'] = df['Экспертиза промышленной безопасности'].astype(float).div(df['Экспертиза промышленной безопасности'].sum())
df['new_Готовность'] = df['Готовность к ликвидации последствий аварий и инцидентов'].astype(float).div(df['Готовность к ликвидации последствий аварий и инцидентов'].sum())
df['new_Оформление'] = df['Оформление информационными знаками и знаками безопасности'].astype(float).div(df['Оформление информационными знаками и знаками безопасности'].sum())
df['new_Содержание'] = df['Содержание объектов и оборудования '].astype(float).div(df['Содержание объектов и оборудования '].sum())
df['new_ОЗ'] = df['Охранные зоны (ОЗ)'].astype(float).div(df['Охранные зоны (ОЗ)'].sum())
df['new_Организация'] = df['Организация рабочего процесса и безопасности персонала'].astype(float).div(df['Организация рабочего процесса и безопасности персонала'].sum())

# %%
df.head()
# Out:
#    Документация   Экспертиза промышленной безопасности  \
# 0       1.000000                              0.714286
# 1       1.400000                              1.000000
# 2       1.000000                              3.000000
# 3       0.428571                              0.600000
# 4       1.000000                              1.000000
#
#    Готовность к ликвидации последствий аварий и инцидентов  \
# 0                                           1.000000
# 1                                           0.333333
# 2                                           1.000000
# 3                                           0.333333
# 4                                           1.000000
#
#    Оформление информационными знаками и знаками безопасности  \
# 0                                           2.333333
# 1                                           1.666667
# 2                                           3.000000
# 3                                           1.000000
# 4                                           1.666667
#
#    Содержание объектов и оборудования   Охранные зоны (ОЗ)  \
# 0                                  1.0            0.714286
# 1                                  1.0            1.000000
# 2                                  1.0            0.714286
# 3                                  0.6            0.600000
# 4                                  1.0            1.285714
#
#    Организация рабочего процесса и безопасности персонала  new_Документация  \
# 0                                           1.000000               0.138340
# 1                                           1.000000               0.193676
# 2                                           0.777778               0.138340
# 3                                           0.333333               0.059289
# 4                                           1.000000               0.138340
#
#    new_Экспертиза  new_Готовность  new_Оформление  new_Содержание    new_ОЗ  \
# 0        0.085911        0.157421        0.162791        0.156794  0.108225
# 1        0.120275        0.052474        0.116279        0.156794  0.151515
# 2        0.360825        0.157421        0.209302        0.156794  0.108225
# 3        0.072165        0.052474        0.069767        0.094077  0.090909
# 4        0.120275        0.157421        0.116279        0.156794  0.194805
#
#    new_Организация
# 0         0.169811
# 1         0.169811
# 2         0.132075
# 3         0.056604
# 4         0.169811

# %%
# Получили новую таблицу теперь отделим значения нашей матрицы от основной таблицы
df_new = df[['new_Документация', 'new_Экспертиза', 'new_Готовность', 'new_Оформление', 'new_Содержание', 'new_ОЗ', 'new_Организация']]
df_new
# Out:
#    new_Документация  new_Экспертиза  new_Готовность  new_Оформление  \
# 0          0.138340        0.085911        0.157421        0.162791
# 1          0.193676        0.120275        0.052474        0.116279
# 2          0.138340        0.360825        0.157421        0.209302
# 3          0.059289        0.072165        0.052474        0.069767
# 4          0.138340        0.120275        0.157421        0.116279
# 5          0.193676        0.120275        0.220390        0.116279
# 6          0.138340        0.120275        0.202399        0.209302
#
#    new_Содержание    new_ОЗ  new_Организация
# 0        0.156794  0.108225         0.169811
# 1        0.156794  0.151515         0.169811
# 2        0.156794  0.108225         0.132075
# 3        0.094077  0.090909         0.056604
# 4        0.156794  0.194805         0.169811
# 5        0.121951  0.151515         0.132075
# 6        0.156794  0.194805         0.169811

# %%
#Вычислим средние значение по строке и запишем полученный результот в mean
df_new['mean'] = df_new.mean(axis=1)
df_new.head()
# Out:
# C:\Users\user\anaconda3\envs\envpy3.5\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#    new_Документация  new_Экспертиза  new_Готовность  new_Оформление  \
# 0          0.138340        0.085911        0.157421        0.162791
# 1          0.193676        0.120275        0.052474        0.116279
# 2          0.138340        0.360825        0.157421        0.209302
# 3          0.059289        0.072165        0.052474        0.069767
# 4          0.138340        0.120275        0.157421        0.116279
#
#    new_Содержание    new_ОЗ  new_Организация      mean
# 0        0.156794  0.108225         0.169811  0.139899
# 1        0.156794  0.151515         0.169811  0.137261
# 2        0.156794  0.108225         0.132075  0.180426
# 3        0.094077  0.090909         0.056604  0.070755
# 4        0.156794  0.194805         0.169811  0.150532

# %%
#проверка, среднее значение в сумме должно быть равно 1
df_new['mean'].sum()
# Out:
# 0.9999999999999999

# %%
# Далее проведем проверку на согласованность, 
#для этого создадим из нашей полученной выше таблицы матрицы для дальнейшего их перемножения
df_new8 =df_new['mean']

# удаляем из нашей таблицы значениея столбцы mean
#df_new.pop('mean')

df_new1 =DF_1.loc[0]

df_new2 =DF_1.loc[1]

df_new3 =DF_1.loc[2]

df_new4 =DF_1.loc[3]

df_new5 =DF_1.loc[4]

df_new6 =DF_1.loc[5]

df_new7 =DF_1.loc[6]

# %%
#Проверка на согласованность
res1 = np.dot(df_new1,df_new8)
print(res1)
res2 = np.dot(df_new2,df_new8)
print(res2)
res3 = np.dot(df_new3,df_new8)
print(res3)
res4 = np.dot(df_new4,df_new8)
print(res4)
res5 = np.dot(df_new5,df_new8)
print(res5)
res6 = np.dot(df_new6,df_new8)
print(res6)
res7 = np.dot(df_new7,df_new8)
print(res7)
# Out:
# 1.012013888091239
# 0.9828454262711375
# 1.335089836157601
# 0.5108064899971555
# 1.0902785583878138
# 1.1040157985400263
# 1.23616874611759

# %%
sum_new = res1 + res2 + res3 + res4 + res5 + res6 + res7
print(sum_new)
# Out:
# 7.271218743562563

# %%
# Вычислем значения CI, RI, CR
CI = (sum_new - 7)/(7-1)
print(CI)
RI = (1.98*(7-2))/7
print(RI)
CR = CI/RI
print(CR)
# Out:
# 0.0452031239270938
# 1.4142857142857144
# 0.03196180479693501

# %%
# Получилось, что значение CR=0.032, что менеше 0,1 значит матрицу можно считать согласованной
# Проделаем аналогичные действия с другими экспертами
