# %% [markdown]
# # Загрузка данных анкет и проведение МАИ, анализ полученных результатов
# Данные: заполненные анкеты экспертов (таблицы Excel)

# %%
import re
import numpy as np
import pandas as pd
import scipy as sp
import matplotlib.pyplot as plt
from random import randint

# %%
df = pd.read_excel(r'C:\Users\user\предпосылки\Экс1.xlsx')
df.head()
# Out:
#                                        Тип нарушения  Документация   \
# 0                                      Документация               1
# 1               Экспертиза промышленной безопасности              1
# 2  Готовность к ликвидации последствий аварий и и...              2
# 3  Оформление информационными знаками и знаками б...              3
# 4                 Содержание объектов и оборудования              9
#
#    Экспертиза промышленной безопасности  \
# 0                              1.000000
# 1                              1.000000
# 2                              1.666667
# 3                              2.500000
# 4                              4.500000
#
#    Готовность к ликвидации последствий аварий и инцидентов  \
# 0                                               0.50
# 1                                               0.60
# 2                                               1.00
# 3                                               0.50
# 4                                               2.25
#
#    Оформление информационными знаками и знаками безопасности  \
# 0                                           0.333333
# 1                                           0.400000
# 2                                           2.000000
# 3                                           1.000000
# 4                                           3.000000
#
#    Содержание объектов и оборудования   Охранные зоны (ОЗ)  \
# 0                             0.111111            0.250000
# 1                             0.222222            0.285714
# 2                             0.444444            0.714286
# 3                             0.333333            1.000000
# 4                             1.000000            1.285714
#
#    Организация рабочего процесса и безопасности персонала
# 0                                           0.111111
# 1                                           0.111111
# 2                                           0.555556
# 3                                           0.222222
# 4                                           1.000000

# %%
print('Число строк и столбцов в наборе данных:\n', df.shape)
# Out:
# Число строк и столбцов в наборе данных:
#  (7, 8)

# %%
# типы столбцов 
df.dtypes
# Out:
# Тип нарушения                                                 object
# Документация                                                   int64
# Экспертиза промышленной безопасности                         float64
# Готовность к ликвидации последствий аварий и инцидентов      float64
# Оформление информационными знаками и знаками безопасности    float64
# Содержание объектов и оборудования                           float64
# Охранные зоны (ОЗ)                                           float64
# Организация рабочего процесса и безопасности персонала       float64
# dtype: object

# %%
#удаление столбца типа object для дальнейшей работы с фреймом 
df.pop('Тип нарушения') 
print(df)
# Out:
#    Документация   Экспертиза промышленной безопасности  \
# 0              1                              1.000000
# 1              1                              1.000000
# 2              2                              1.666667
# 3              3                              2.500000
# 4              9                              4.500000
# 5              4                              3.500000
# 6              9                              9.000000
#
#    Готовность к ликвидации последствий аварий и инцидентов  \
# 0                                               0.50
# 1                                               0.60
# 2                                               1.00
# 3                                               0.50
# 4                                               2.25
# 5                                               1.40
# 6                                               1.80
#
#    Оформление информационными знаками и знаками безопасности  \
# 0                                           0.333333
# 1                                           0.400000
# 2                                           2.000000
# 3                                           1.000000
# 4                                           3.000000
# 5                                           1.000000
# 6                                           4.500000
#
#    Содержание объектов и оборудования   Охранные зоны (ОЗ)  \
# 0                             0.111111            0.250000
# 1                             0.222222            0.285714
# 2                             0.444444            0.714286
# 3                             0.333333            1.000000
# 4                             1.000000            1.285714
# 5                             0.777778            1.000000
# 6                             1.000000            2.250000
#
#    Организация рабочего процесса и безопасности персонала
# 0                                           0.111111
# 1                                           0.111111
# 2                                           0.555556
# 3                                           0.222222
# 4                                           1.000000
# 5                                           0.444444
# 6                                           1.000000

# %%
# типы столбцов 
df.dtypes
# Out:
# Документация                                                   int64
# Экспертиза промышленной безопасности                         float64
# Готовность к ликвидации последствий аварий и инцидентов      float64
# Оформление информационными знаками и знаками безопасности    float64
# Содержание объектов и оборудования                           float64
# Охранные зоны (ОЗ)                                           float64
# Организация рабочего процесса и безопасности персонала       float64
# dtype: object

# %%
# также меням тип данных Документации
df['Документация '] = df['Документация '].astype(float)

# %%
df.loc[:, df.columns[df.dtypes == 'float64']].head(7)
# Out:
#    Документация   Экспертиза промышленной безопасности  \
# 0            1.0                              1.000000
# 1            1.0                              1.000000
# 2            2.0                              1.666667
# 3            3.0                              2.500000
# 4            9.0                              4.500000
# 5            4.0                              3.500000
# 6            9.0                              9.000000
#
#    Готовность к ликвидации последствий аварий и инцидентов  \
# 0                                               0.50
# 1                                               0.60
# 2                                               1.00
# 3                                               0.50
# 4                                               2.25
# 5                                               1.40
# 6                                               1.80
#
#    Оформление информационными знаками и знаками безопасности  \
# 0                                           0.333333
# 1                                           0.400000
# 2                                           2.000000
# 3                                           1.000000
# 4                                           3.000000
# 5                                           1.000000
# 6                                           4.500000
#
#    Содержание объектов и оборудования   Охранные зоны (ОЗ)  \
# 0                             0.111111            0.250000
# 1                             0.222222            0.285714
# 2                             0.444444            0.714286
# 3                             0.333333            1.000000
# 4                             1.000000            1.285714
# 5                             0.777778            1.000000
# 6                             1.000000            2.250000
#
#    Организация рабочего процесса и безопасности персонала
# 0                                           0.111111
# 1                                           0.111111
# 2                                           0.555556
# 3                                           0.222222
# 4                                           1.000000
# 5                                           0.444444
# 6                                           1.000000

# %%
DF_1=df[:].copy()

# %%
#Найдем сумму всех столбцов, для того чтобы в дальнейшем пересчитать полученные значения
df.sum ()
# Out:
# Документация                                                 29.000000
# Экспертиза промышленной безопасности                         23.166667
# Готовность к ликвидации последствий аварий и инцидентов       8.050000
# Оформление информационными знаками и знаками безопасности    12.233333
# Содержание объектов и оборудования                            3.888889
# Охранные зоны (ОЗ)                                            6.785714
# Организация рабочего процесса и безопасности персонала        3.444444
# dtype: float64

# %%
# Считаем значения для нашей матрицы, путем деления каждого значения в столбце на сумму столбца
df['new_Документация'] = df['Документация '].astype(float).div(df['Документация '].sum())
df['new_Экспертиза'] = df['Экспертиза промышленной безопасности'].astype(float).div(df['Экспертиза промышленной безопасности'].sum())
df['new_Готовность'] = df['Готовность к ликвидации последствий аварий и инцидентов'].astype(float).div(df['Готовность к ликвидации последствий аварий и инцидентов'].sum())
df['new_Оформление'] = df['Оформление информационными знаками и знаками безопасности'].astype(float).div(df['Оформление информационными знаками и знаками безопасности'].sum())
df['new_Содержание'] = df['Содержание объектов и оборудования '].astype(float).div(df['Содержание объектов и оборудования '].sum())
df['new_ОЗ'] = df['Охранные зоны (ОЗ)'].astype(float).div(df['Охранные зоны (ОЗ)'].sum())
df['new_Организация'] = df['Организация рабочего процесса и безопасности персонала'].astype(float).div(df['Организация рабочего процесса и безопасности персонала'].sum())

# %%
df.head()
# Out:
#    Документация   Экспертиза промышленной безопасности  \
# 0            1.0                              1.000000
# 1            1.0                              1.000000
# 2            2.0                              1.666667
# 3            3.0                              2.500000
# 4            9.0                              4.500000
#
#    Готовность к ликвидации последствий аварий и инцидентов  \
# 0                                               0.50
# 1                                               0.60
# 2                                               1.00
# 3                                               0.50
# 4                                               2.25
#
#    Оформление информационными знаками и знаками безопасности  \
# 0                                           0.333333
# 1                                           0.400000
# 2                                           2.000000
# 3                                           1.000000
# 4                                           3.000000
#
#    Содержание объектов и оборудования   Охранные зоны (ОЗ)  \
# 0                             0.111111            0.250000
# 1                             0.222222            0.285714
# 2                             0.444444            0.714286
# 3                             0.333333            1.000000
# 4                             1.000000            1.285714
#
#    Организация рабочего процесса и безопасности персонала  new_Документация  \
# 0                                           0.111111               0.034483
# 1                                           0.111111               0.034483
# 2                                           0.555556               0.068966
# 3                                           0.222222               0.103448
# 4                                           1.000000               0.310345
#
#    new_Экспертиза  new_Готовность  new_Оформление  new_Содержание    new_ОЗ  \
# 0        0.043165        0.062112        0.027248        0.028571  0.036842
# 1        0.043165        0.074534        0.032698        0.057143  0.042105
# 2        0.071942        0.124224        0.163488        0.114286  0.105263
# 3        0.107914        0.062112        0.081744        0.085714  0.147368
# 4        0.194245        0.279503        0.245232        0.257143  0.189474
#
#    new_Организация
# 0         0.032258
# 1         0.032258
# 2         0.161290
# 3         0.064516
# 4         0.290323

# %%
# Получили новую таблицу теперь отделим значения нашей матрицы от основной таблицы
df_new = df[['new_Документация', 'new_Экспертиза', 'new_Готовность', 'new_Оформление', 'new_Содержание', 'new_ОЗ', 'new_Организация']]
df_new
# Out:
#    new_Документация  new_Экспертиза  new_Готовность  new_Оформление  \
# 0          0.034483        0.043165        0.062112        0.027248
# 1          0.034483        0.043165        0.074534        0.032698
# 2          0.068966        0.071942        0.124224        0.163488
# 3          0.103448        0.107914        0.062112        0.081744
# 4          0.310345        0.194245        0.279503        0.245232
# 5          0.137931        0.151079        0.173913        0.081744
# 6          0.310345        0.388489        0.223602        0.367847
#
#    new_Содержание    new_ОЗ  new_Организация
# 0        0.028571  0.036842         0.032258
# 1        0.057143  0.042105         0.032258
# 2        0.114286  0.105263         0.161290
# 3        0.085714  0.147368         0.064516
# 4        0.257143  0.189474         0.290323
# 5        0.200000  0.147368         0.129032
# 6        0.257143  0.331579         0.290323

# %%
#Вычислим средние значение по строке и запишем полученный результот в mean
df_new['mean'] = df_new.mean(axis=1)
df_new.head()
# Out:
# C:\Users\user\anaconda3\envs\envpy3.5\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#    new_Документация  new_Экспертиза  new_Готовность  new_Оформление  \
# 0          0.034483        0.043165        0.062112        0.027248
# 1          0.034483        0.043165        0.074534        0.032698
# 2          0.068966        0.071942        0.124224        0.163488
# 3          0.103448        0.107914        0.062112        0.081744
# 4          0.310345        0.194245        0.279503        0.245232
#
#    new_Содержание    new_ОЗ  new_Организация      mean
# 0        0.028571  0.036842         0.032258  0.037811
# 1        0.057143  0.042105         0.032258  0.045198
# 2        0.114286  0.105263         0.161290  0.115637
# 3        0.085714  0.147368         0.064516  0.093259
# 4        0.257143  0.189474         0.290323  0.252323

# %%
#проверка, среднее значение в сумме должно быть равно 1
df_new['mean'].sum()
# Out:
# 1.0

# %%
# Далее проведем проверку на согласованность, 
#для этого создадим из нашей полученной выше таблицы матрицы для дальнейшего их перемножения
df_new8 =df_new['mean']

# удаляем из нашей таблицы значениея столбцы mean
#df_new.pop('mean')

df_new1 =DF_1.loc[0]

df_new2 =DF_1.loc[1]

df_new3 =DF_1.loc[2]

df_new4 =DF_1.loc[3]

df_new5 =DF_1.loc[4]

df_new6 =DF_1.loc[5]

df_new7 =DF_1.loc[6]

# %%
#Проверка на согласованность
res1 = np.dot(df_new1,df_new8)
print(res1)
res2 = np.dot(df_new2,df_new8)
print(res2)
res3 = np.dot(df_new3,df_new8)
print(res3)
res4 = np.dot(df_new4,df_new8)
print(res4)
res5 = np.dot(df_new5,df_new8)
print(res5)
res6 = np.dot(df_new6,df_new8)
print(res6)
res7 = np.dot(df_new7,df_new8)
print(res7)
# Out:
# 0.27085076135418096
# 0.32187720805526515
# 0.8416118824645268
# 0.6763492701825311
# 1.833425392959434
# 1.0444431570295836
# 2.2653263857899266

# %%
sum_new = res1 + res2 + res3 + res4 + res5 + res6 + res7
print(sum_new)
# Out:
# 7.253884057835448

# %%
# Вычислем значения CI, RI, CR
CI = (sum_new - 7)/(7-1)
print(CI)
RI = (1.98*(7-2))/7
print(RI)
CR = CI/RI
print(CR)
# Out:
# 0.04231400963924129
# 1.4142857142857144
# 0.029918996714615054

# %%
# Получилось, что значение CR=0.03, что менеше 0,1 значит матрицу можно считать согласованной
# Проделаем аналогичные действия с другими экспертами
