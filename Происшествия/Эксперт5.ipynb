# %% [markdown]
# # Загрузка данных анкет и проведение МАИ, анализ полученных результатов
# Данные: заполненные анкеты экспертов (таблицы Excel)

# %%
import re
import numpy as np
import pandas as pd
import scipy as sp
import matplotlib.pyplot as plt
from random import randint

# %%
df = pd.read_excel(r'C:\Users\user\предпосылки\Экс5.xlsx')
df.head()
# Out:
#                                        Тип нарушения  Документация   \
# 0                                      Документация               1
# 1               Экспертиза промышленной безопасности              5
# 2  Готовность к ликвидации последствий аварий и и...              5
# 3  Оформление информационными знаками и знаками б...              5
# 4                 Содержание объектов и оборудования              7
#
#    Экспертиза промышленной безопасности  \
# 0                                   0.2
# 1                                   1.0
# 2                                   1.0
# 3                                   1.0
# 4                                   5.0
#
#    Готовность к ликвидации последствий аварий и инцидентов  \
# 0                                                0.2
# 1                                                1.0
# 2                                                1.0
# 3                                                0.2
# 4                                                1.0
#
#    Оформление информационными знаками и знаками безопасности  \
# 0                                                0.2
# 1                                                1.0
# 2                                                5.0
# 3                                                1.0
# 4                                                7.0
#
#    Содержание объектов и оборудования   Охранные зоны (ОЗ)  \
# 0                             0.142857            0.200000
# 1                             0.200000            0.200000
# 2                             1.000000            1.000000
# 3                             0.142857            0.333333
# 4                             1.000000            5.000000
#
#    Организация рабочего процесса и безопасности персонала
# 0                                           0.142857
# 1                                           0.200000
# 2                                           1.000000
# 3                                           0.200000
# 4                                           3.000000

# %%
print('Число строк и столбцов в наборе данных:\n', df.shape)
# Out:
# Число строк и столбцов в наборе данных:
#  (7, 8)

# %%
# типы столбцов 
df.dtypes
# Out:
# Тип нарушения                                                 object
# Документация                                                   int64
# Экспертиза промышленной безопасности                         float64
# Готовность к ликвидации последствий аварий и инцидентов      float64
# Оформление информационными знаками и знаками безопасности    float64
# Содержание объектов и оборудования                           float64
# Охранные зоны (ОЗ)                                           float64
# Организация рабочего процесса и безопасности персонала       float64
# dtype: object

# %%
#удаление столбца типа object для дальнейшей работы с фреймом 
df.pop('Тип нарушения') 
print(df)
# Out:
#    Документация   Экспертиза промышленной безопасности  \
# 0              1                                   0.2
# 1              5                                   1.0
# 2              5                                   1.0
# 3              5                                   1.0
# 4              7                                   5.0
# 5              5                                   5.0
# 6              7                                   5.0
#
#    Готовность к ликвидации последствий аварий и инцидентов  \
# 0                                                0.2
# 1                                                1.0
# 2                                                1.0
# 3                                                0.2
# 4                                                1.0
# 5                                                1.0
# 6                                                1.0
#
#    Оформление информационными знаками и знаками безопасности  \
# 0                                                0.2
# 1                                                1.0
# 2                                                5.0
# 3                                                1.0
# 4                                                7.0
# 5                                                3.0
# 6                                                5.0
#
#    Содержание объектов и оборудования   Охранные зоны (ОЗ)  \
# 0                             0.142857            0.200000
# 1                             0.200000            0.200000
# 2                             1.000000            1.000000
# 3                             0.142857            0.333333
# 4                             1.000000            5.000000
# 5                             0.200000            1.000000
# 6                             0.333333            3.000000
#
#    Организация рабочего процесса и безопасности персонала
# 0                                           0.142857
# 1                                           0.200000
# 2                                           1.000000
# 3                                           0.200000
# 4                                           3.000000
# 5                                           0.333333
# 6                                           1.000000

# %%
# типы столбцов 
df.dtypes
# Out:
# Документация                                                   int64
# Экспертиза промышленной безопасности                         float64
# Готовность к ликвидации последствий аварий и инцидентов      float64
# Оформление информационными знаками и знаками безопасности    float64
# Содержание объектов и оборудования                           float64
# Охранные зоны (ОЗ)                                           float64
# Организация рабочего процесса и безопасности персонала       float64
# dtype: object

# %%
# также меням тип данных Документации
df['Документация '] = df['Документация '].astype(float)

# %%
df.loc[:, df.columns[df.dtypes == 'float64']].head(7)
# Out:
#    Документация   Экспертиза промышленной безопасности  \
# 0            1.0                                   0.2
# 1            5.0                                   1.0
# 2            5.0                                   1.0
# 3            5.0                                   1.0
# 4            7.0                                   5.0
# 5            5.0                                   5.0
# 6            7.0                                   5.0
#
#    Готовность к ликвидации последствий аварий и инцидентов  \
# 0                                                0.2
# 1                                                1.0
# 2                                                1.0
# 3                                                0.2
# 4                                                1.0
# 5                                                1.0
# 6                                                1.0
#
#    Оформление информационными знаками и знаками безопасности  \
# 0                                                0.2
# 1                                                1.0
# 2                                                5.0
# 3                                                1.0
# 4                                                7.0
# 5                                                3.0
# 6                                                5.0
#
#    Содержание объектов и оборудования   Охранные зоны (ОЗ)  \
# 0                             0.142857            0.200000
# 1                             0.200000            0.200000
# 2                             1.000000            1.000000
# 3                             0.142857            0.333333
# 4                             1.000000            5.000000
# 5                             0.200000            1.000000
# 6                             0.333333            3.000000
#
#    Организация рабочего процесса и безопасности персонала
# 0                                           0.142857
# 1                                           0.200000
# 2                                           1.000000
# 3                                           0.200000
# 4                                           3.000000
# 5                                           0.333333
# 6                                           1.000000

# %%
DF_1=df[:].copy()

# %%
#Найдем сумму всех столбцов, для того чтобы в дальнейшем пересчитать полученные значения
df.sum ()
# Out:
# Документация                                                 35.000000
# Экспертиза промышленной безопасности                         18.200000
# Готовность к ликвидации последствий аварий и инцидентов       5.400000
# Оформление информационными знаками и знаками безопасности    22.200000
# Содержание объектов и оборудования                            3.019048
# Охранные зоны (ОЗ)                                           10.733333
# Организация рабочего процесса и безопасности персонала        5.876190
# dtype: float64

# %%
# Считаем значения для нашей матрицы, путем деления каждого значения в столбце на сумму столбца
df['new_Документация'] = df['Документация '].astype(float).div(df['Документация '].sum())
df['new_Экспертиза'] = df['Экспертиза промышленной безопасности'].astype(float).div(df['Экспертиза промышленной безопасности'].sum())
df['new_Готовность'] = df['Готовность к ликвидации последствий аварий и инцидентов'].astype(float).div(df['Готовность к ликвидации последствий аварий и инцидентов'].sum())
df['new_Оформление'] = df['Оформление информационными знаками и знаками безопасности'].astype(float).div(df['Оформление информационными знаками и знаками безопасности'].sum())
df['new_Содержание'] = df['Содержание объектов и оборудования '].astype(float).div(df['Содержание объектов и оборудования '].sum())
df['new_ОЗ'] = df['Охранные зоны (ОЗ)'].astype(float).div(df['Охранные зоны (ОЗ)'].sum())
df['new_Организация'] = df['Организация рабочего процесса и безопасности персонала'].astype(float).div(df['Организация рабочего процесса и безопасности персонала'].sum())

# %%
df.head()
# Out:
#    Документация   Экспертиза промышленной безопасности  \
# 0            1.0                                   0.2
# 1            5.0                                   1.0
# 2            5.0                                   1.0
# 3            5.0                                   1.0
# 4            7.0                                   5.0
#
#    Готовность к ликвидации последствий аварий и инцидентов  \
# 0                                                0.2
# 1                                                1.0
# 2                                                1.0
# 3                                                0.2
# 4                                                1.0
#
#    Оформление информационными знаками и знаками безопасности  \
# 0                                                0.2
# 1                                                1.0
# 2                                                5.0
# 3                                                1.0
# 4                                                7.0
#
#    Содержание объектов и оборудования   Охранные зоны (ОЗ)  \
# 0                             0.142857            0.200000
# 1                             0.200000            0.200000
# 2                             1.000000            1.000000
# 3                             0.142857            0.333333
# 4                             1.000000            5.000000
#
#    Организация рабочего процесса и безопасности персонала  new_Документация  \
# 0                                           0.142857               0.028571
# 1                                           0.200000               0.142857
# 2                                           1.000000               0.142857
# 3                                           0.200000               0.142857
# 4                                           3.000000               0.200000
#
#    new_Экспертиза  new_Готовность  new_Оформление  new_Содержание    new_ОЗ  \
# 0        0.010989        0.037037        0.009009        0.047319  0.018634
# 1        0.054945        0.185185        0.045045        0.066246  0.018634
# 2        0.054945        0.185185        0.225225        0.331230  0.093168
# 3        0.054945        0.037037        0.045045        0.047319  0.031056
# 4        0.274725        0.185185        0.315315        0.331230  0.465839
#
#    new_Организация
# 0         0.024311
# 1         0.034036
# 2         0.170178
# 3         0.034036
# 4         0.510535

# %%
# Получили новую таблицу теперь отделим значения нашей матрицы от основной таблицы
df_new = df[['new_Документация', 'new_Экспертиза', 'new_Готовность', 'new_Оформление', 'new_Содержание', 'new_ОЗ', 'new_Организация']]
df_new
# Out:
#    new_Документация  new_Экспертиза  new_Готовность  new_Оформление  \
# 0          0.028571        0.010989        0.037037        0.009009
# 1          0.142857        0.054945        0.185185        0.045045
# 2          0.142857        0.054945        0.185185        0.225225
# 3          0.142857        0.054945        0.037037        0.045045
# 4          0.200000        0.274725        0.185185        0.315315
# 5          0.142857        0.274725        0.185185        0.135135
# 6          0.200000        0.274725        0.185185        0.225225
#
#    new_Содержание    new_ОЗ  new_Организация
# 0        0.047319  0.018634         0.024311
# 1        0.066246  0.018634         0.034036
# 2        0.331230  0.093168         0.170178
# 3        0.047319  0.031056         0.034036
# 4        0.331230  0.465839         0.510535
# 5        0.066246  0.093168         0.056726
# 6        0.110410  0.279503         0.170178

# %%
#Вычислим средние значение по строке и запишем полученный результот в mean
df_new['mean'] = df_new.mean(axis=1)
df_new.head()
# Out:
# C:\Users\user\anaconda3\envs\envpy3.5\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#    new_Документация  new_Экспертиза  new_Готовность  new_Оформление  \
# 0          0.028571        0.010989        0.037037        0.009009
# 1          0.142857        0.054945        0.185185        0.045045
# 2          0.142857        0.054945        0.185185        0.225225
# 3          0.142857        0.054945        0.037037        0.045045
# 4          0.200000        0.274725        0.185185        0.315315
#
#    new_Содержание    new_ОЗ  new_Организация      mean
# 0        0.047319  0.018634         0.024311  0.025124
# 1        0.066246  0.018634         0.034036  0.078135
# 2        0.331230  0.093168         0.170178  0.171827
# 3        0.047319  0.031056         0.034036  0.056042
# 4        0.331230  0.465839         0.510535  0.326118

# %%
#проверка, среднее значение в сумме должно быть равно 1
df_new['mean'].sum()
# Out:
# 1.0

# %%
# Далее проведем проверку на согласованность, 
#для этого создадим из нашей полученной выше таблицы матрицы для дальнейшего их перемножения
df_new8 =df_new['mean']

# удаляем из нашей таблицы значениея столбцы mean
#df_new.pop('mean')

df_new1 =DF_1.loc[0]

df_new2 =DF_1.loc[1]

df_new3 =DF_1.loc[2]

df_new4 =DF_1.loc[3]

df_new5 =DF_1.loc[4]

df_new6 =DF_1.loc[5]

df_new7 =DF_1.loc[6]

# %%
#Проверка на согласованность
res1 = np.dot(df_new1,df_new8)
print(res1)
res2 = np.dot(df_new2,df_new8)
print(res2)
res3 = np.dot(df_new3,df_new8)
print(res3)
res4 = np.dot(df_new4,df_new8)
print(res4)
res5 = np.dot(df_new5,df_new8)
print(res5)
res6 = np.dot(df_new6,df_new8)
print(res6)
res7 = np.dot(df_new7,df_new8)
print(res7)
# Out:
# 0.18966629317411987
# 0.5653999923687572
# 1.324665297151976
# 0.4274753041971325
# 2.757628720466771
# 1.1265872284073928
# 1.7426266218132853

# %%
sum_new = res1 + res2 + res3 + res4 + res5 + res6 + res7
print(sum_new)
# Out:
# 8.134049457579435

# %%
# Вычислем значения CI, RI, CR
CI = (sum_new - 7)/(7-1)
print(CI)
RI = (1.98*(7-2))/7
print(RI)
CR = CI/RI
print(CR)
# Out:
# 0.1890082429299058
# 1.4142857142857144
# 0.13364219197064048

# %%
# Получилось, что значение CR=0.13, что большее 0,1 значит матрицу нельзя считать согласованной
# Проделаем аналогичные действия с другими экспертами
